# %% [markdown]
# <a href="https://colab.research.google.com/github/shareefat/folio/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dataset imported from kaggle

# %%
import pandas as pd
df = pd.read_csv('retail_price.csv')
df.head()
# Out:
#   product_id product_category_name  month_year  qty  total_price  \
# 0       bed1        bed_bath_table  01-05-2017    1        45.95
# 1       bed1        bed_bath_table  01-06-2017    3       137.85
# 2       bed1        bed_bath_table  01-07-2017    6       275.70
# 3       bed1        bed_bath_table  01-08-2017    4       183.80
# 4       bed1        bed_bath_table  01-09-2017    2        91.90
#
#    freight_price  unit_price  product_name_lenght  product_description_lenght  \
# 0      15.100000       45.95                   39                         161
# 1      12.933333       45.95                   39                         161
# 2      14.840000       45.95                   39                         161
# 3      14.287500       45.95                   39                         161
# 4      15.100000       45.95                   39                         161
#
#    product_photos_qty  ...  comp_1  ps1        fp1      comp_2  ps2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  676 non-null    object
#  1   product_category_name       676 non-null    object
#  2   month_year                  676 non-null    object
#  3   qty                         676 non-null    int64
#  4   total_price                 676 non-null    float64
#  5   freight_price               676 non-null    float64
#  6   unit_price                  676 non-null    float64
#  7   product_name_lenght         676 non-null    int64
#  8   product_description_lenght  676 non-null    int64
#  9   product_photos_qty          676 non-null    int64
#  10  product_weight_g            676 non-null    int64
#  11  product_score               676 non-null    float64
#  12  customers                   676 non-null    int64
# ...

# %%
df.describe()
# Out:
#               qty   total_price  freight_price  unit_price  \
# count  676.000000    676.000000     676.000000  676.000000
# mean    14.495562   1422.708728      20.682270  106.496800
# std     15.443421   1700.123100      10.081817   76.182972
# min      1.000000     19.900000       0.000000   19.900000
# 25%      4.000000    333.700000      14.761912   53.900000
# 50%     10.000000    807.890000      17.518472   89.900000
# 75%     18.000000   1887.322500      22.713558  129.990000
# max    122.000000  12095.000000      79.760000  364.000000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count           676.000000                  676.000000          676.000000
# mean             48.720414                  767.399408            1.994083
# std               9.420715                  655.205015            1.420473
# min              29.000000                  100.000000            1.000000
# ...

# %% [markdown]
# Counting missing value

# %%
df.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# month_year                    0
# qty                           0
# total_price                   0
# freight_price                 0
# unit_price                    0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_score                 0
# customers                     0
# weekday                       0
# weekend                       0
# holiday                       0
# month                         0
# year                          0
# s                             0
# volume                        0
# comp_1                        0
# ps1                           0
# fp1                           0
# comp_2                        0
# ps2                           0
# fp2                           0
# comp_3                        0
# ps3                           0
# fp3                           0
# ...

# %% [markdown]
# Numeric missing values is treating

# %% [markdown]
# cleaning duplicate values

# %%
df.drop_duplicates()
# Out:
#     product_id product_category_name  month_year  qty  total_price  \
# 0         bed1        bed_bath_table  01-05-2017    1        45.95
# 1         bed1        bed_bath_table  01-06-2017    3       137.85
# 2         bed1        bed_bath_table  01-07-2017    6       275.70
# 3         bed1        bed_bath_table  01-08-2017    4       183.80
# 4         bed1        bed_bath_table  01-09-2017    2        91.90
# ..         ...                   ...         ...  ...          ...
# 671       bed5        bed_bath_table  01-05-2017    1       215.00
# 672       bed5        bed_bath_table  01-06-2017   10      2090.00
# 673       bed5        bed_bath_table  01-07-2017   59     12095.00
# 674       bed5        bed_bath_table  01-08-2017   52     10375.00
# 675       bed5        bed_bath_table  01-09-2017   32      5222.36
#
#      freight_price  unit_price  product_name_lenght  \
# 0        15.100000   45.950000                   39
# 1        12.933333   45.950000                   39
# ...

# %% [markdown]
# check the outline

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x=df['product_category_name'],y=df['qty'])
plt.title('plot for quantity and name')
plt.show()

# %% [markdown]
# 20 visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('retail_price.csv')
sns.violinplot(data=df, x='total_price',palette='coolwarm' )
plt.title('plot for ')
plt.show()
# Out:
# <ipython-input-22-411382eb8e92>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='total_price',palette='coolwarm' )

# %%
sns.boxplot(data=df, x='total_price',y='product_category_name',palette='deep' )
plt.title('plot for total price by category ')
plt.show()
#
# Out:
# <ipython-input-24-577e86c61a0f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='total_price',y='product_category_name',palette='deep' )

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['total_price'],bins=10,kde=True,color='red')
plt.title('plot for total price')
plt.show()

# %%
sns.pairplot(df[['product_category_name','qty','total_price']],hue='total_price',palette='Set2')
plt.show()

# %%
sns.pairplot(df[['product_category_name','qty','total_price']])
plt.show()

# %%
df['Date'] = pd.to_datetime(df['month_year'])
df.groupby(df['Date'].dt.year)['total_price'].sum().plot(kind='line', figsize=(10, 6))
plt.title('plot for total price by year')
plt.xlabel('year')
plt.ylabel('total price')
plt.show()

# %%
category=df.groupby(['product_category_name','qty'])['total_price'].sum().unstack()
category.plot(kind='bar',stacked=True,legend=False,figsize=(10,6))
plt.title('plot for total price by category')
plt.xlabel('category')
plt.ylabel('total price')
plt.show()

# %%
top_sales=df.groupby('product_id')['total_price'].sum().sort_values(ascending=False).head(10)
top_sales.plot(kind='bar',color='red')
plt.title('plot for top sales')
plt.xlabel('product_id')
plt.ylabel('total price')
plt.show()

# %%
sns.scatterplot(data=df,x='month',y='qty',color='red',)
plt.title('Quantity by Month')
plt.show()

# %%
category=df.groupby('product_category_name')['total_price'].sum()
category.plot(kind='pie', wedgeprops={'width': 0.3},autopct='%1.1f%%',startangle=90)
plt.title('Total Price by (pie)')
plt.ylabel('')
plt.show()

# %%
import plotly.express as px
fig = px.treemap(df, path=['product_category_name'], values='total_price',color='product_category_name',color_continuous_scale='viridis')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.kdeplot(df['total_price'],shade=True,color='red')
plt.title('plot for total price')
plt.xlabel('total price')
plt.ylabel('density')
plt.show()
# Out:
# <ipython-input-71-0047bc312db7>:1: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.

# %%
sns.scatterplot(data=df,x='month',y='qty',size='total_price',hue='product_category_name',sizes=(20,200),palette='viridis')
plt.title('Quantity by Month')
plt.show()

# %%
sns.pairplot(df[['product_category_name','total_price','month']])
plt.title("plot for product category name and total price (scatter plot)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
categories = df[df['product_category_name'] == 'bed_bath_table']
bed_bath_table = categories.groupby("product_id")['total_price'].sum().sort_values(ascending=False).head(5)
sns.barplot(x=bed_bath_table.values, y=bed_bath_table.index, palette='coolwarm')
plt.title('plot for bed bath table')
plt.xlabel('total price')
plt.ylabel('product id')
plt.show()
# Out:
# <ipython-input-85-448f9df605f3>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
